# %%
pip install pyroomacoustics
# Out:
# Collecting pyroomacoustics
#   Downloading pyroomacoustics-0.8.4-cp38-cp38-win_amd64.whl (34.4 MB)
# Requirement already satisfied: scipy>=0.18.0 in c:\users\usuario\anaconda3\lib\site-packages (from pyroomacoustics) (1.5.2)
# Requirement already satisfied: numpy>=1.13.0 in c:\users\usuario\anaconda3\lib\site-packages (from pyroomacoustics) (1.19.2)
# Collecting pybind11>=2.2
#   Downloading pybind11-2.13.6-py3-none-any.whl (243 kB)
# Requirement already satisfied: Cython in c:\users\usuario\anaconda3\lib\site-packages (from pyroomacoustics) (0.29.21)
# Installing collected packages: pybind11, pyroomacoustics
# Successfully installed pybind11-2.13.6 pyroomacoustics-0.8.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import correlate
import pyroomacoustics as pra
import soundfile as sf
from IPython.display import Audio

# %%
signal, fs = sf.read("vox.wav")
print(f"Frecuencia de muestreo: {fs} Hz")
# Out:
# Frecuencia de muestreo: 44100 Hz

# %% [markdown]
# #### SIMULACIÓN DEL ENTORNO ACÚSTICO
#
# Crear una habitación.
#
# Ubicar una fuente sonora.
#
# Posicionar 4 micrófonos lineales separados por 10 cm.

# %%
room_dim = [5, 4]  # Dimensiones de la sala 
mic_distancia = 0.1  # Separación de micrófonos en metros

# Coordenadas de los micrófonos
mic_start = [2, 1]  # posición del primer micrófono
mic_positions = np.array([
    [mic_start[0] + i * mic_distancia, mic_start[1]] for i in range(4)
]).T

# Crear sala y agregar fuente
room = pra.ShoeBox(room_dim, fs=44100, max_order=3)
source_position = [3, 3]
room.add_source(source_position, signal=signal)

# Agregar arreglo de micrófonos
room.add_microphone_array(pra.MicrophoneArray(mic_positions, room.fs))

room.simulate()

# %%
signals = room.mic_array.signals  # señales grabadas por los micrófonos

Audio(signals[0], rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #  Estimación de TDOA (Time Difference of Arrival)

# %%
def estimate_tdoa(sig1, sig2, fs):
    corr = correlate(sig1, sig2, mode='full')
    lag = np.argmax(corr) - (len(sig1) - 1)
    return lag / fs  # tiempo en segundos

# %% [markdown]
# Aplico para cada par de microfonos

# %%
fs = room.fs
tdoa_12 = estimate_tdoa(signals[0], signals[1], fs)
tdoa_23 = estimate_tdoa(signals[1], signals[2], fs)
# etc.

# %% [markdown]
# # Cálculo del ángulo de llegada (DOA)

# %%
c = 343  # velocidad del sonido en m/s

def tdoa_to_angle(tdoa, d, c):
    cos_theta = tdoa * c / d
    cos_theta = np.clip(cos_theta, -1, 1)  # evitar errores numéricos
    return np.degrees(np.arccos(cos_theta))

# %%
angle_12 = tdoa_to_angle(tdoa_12, mic_distancia, c)
