# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset
from scipy.signal import correlate
import pyroomacoustics as pra
import soundfile as sf
from IPython.display import Audio
from scipy.fft import fft, ifft
from scipy.signal import correlate

import doascripts as doa
import simscripts as sim
import plotting as pt
import measuring as meas

# %% [markdown]
# Se define el diccionario base a partir del cual se ajustarán los parámetros pertenecientes a la simulación.

# %%
dicc_base = {
    "room_dim": [5, 5, 5], 
    "rt60": 0.2,
    "mic_amount": 4,
    "mic_start": [1, 1, 1],
    "mic_dist": 0.1,
    "source_pos": [1, 2.5, 1],
    "fs": 48000}
    
sim.expand_param(dicc_base, "rt60", 0.01, n=100,  filename = "variación_rt60")
# Out:
# {'room_dim': [5, 5, 5],
#  'rt60': [0.2,
#   0.21000000000000002,
#   0.22,
#   0.23,
#   0.24000000000000002,
#   0.25,
#   0.26,
#   0.27,
#   0.28,
#   0.29000000000000004,
#   0.30000000000000004,
#   0.31,
#   0.32,
#   0.33,
#   0.34,
#   0.35,
#   0.36,
#   0.37,
#   0.38,
#   0.39,
#   0.4,
#   0.41000000000000003,
#   0.42000000000000004,
#   0.43000000000000005,
#   0.44,
#   0.45,
#   0.46,
#   0.47000000000000003,
#   0.48000000000000004,
#   0.49,
#   0.5,
#   0.51,
#   0.52,
#   0.53,
#   0.54,
#   0.55,
#   0.56,
#   0.5700000000000001,
#   0.5800000000000001,
#   0.5900000000000001,
#   0.6000000000000001,
#   0.6100000000000001,
#   0.62,
#   0.63,
#   0.64,
#   0.65,
#   0.66,
#   0.67,
#   0.6799999999999999,
#   0.69,
#   0.7,
#   0.71,
#   0.72,
#   0.73,
#   0.74,
#   0.75,
#   0.76,
#   0.77,
#   0.78,
#   0.79,
#   0.8,
#   0.81,
#   0.8200000000000001,
#   0.8300000000000001,
#   0.8400000000000001,
#   0.8500000000000001,
#   0.8600000000000001,
#   0.8700000000000001,
#   0.8800000000000001,
#   0.8900000000000001,
#   0.9000000000000001,
#   0.9099999999999999,
#   0.9199999999999999,
#   0.9299999999999999,
#   0.94,
#   0.95,
#   0.96,
#   0.97,
#   0.98,
#   0.99,
#   1.0,
#   1.01,
#   1.02,
#   1.03,
#   1.04,
#   1.05,
#   1.06,
#   1.07,
#   1.08,
#   1.09,
#   1.1,
#   1.11,
#   1.12,
#   1.1300000000000001,
#   1.1400000000000001,
#   1.1500000000000001,
#   1.16,
#   1.17,
#   1.18,
#   1.19],
#  'mic_amount': 4,
#  'mic_start': [1, 1, 1],
#  'mic_dist': 0.1,
#  'source_pos': [1, 2.5, 1],
#  'fs': 48000}

# %%
doa.full_doa_pipeline("variación_rt60.json", "Audios/imp.wav", method="classicfft", variable_param="rt60")
